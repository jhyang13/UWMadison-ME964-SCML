# %%
# Import dependencies
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem 3

# %%
# Define Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Derivative of sigmoid function
def sigmoid_derivative(z):
    return sigmoid(z) * (1 - sigmoid(z))

# Define target output
target = 0

# Perform gradient descent algorithm
def gradient_descent(w, b, learning_rate, epochs):

    costs = []

    for epoch in range(epochs):

        # Forward pass
        z = w * 1 + b  # Input is 1
        
        output = sigmoid(z)
        
        # Calculate the cost (loss)
        cost = 0.5 * (output - target) ** 2
        costs.append(cost)
        
        # Backpropagation - compute gradients
        d_cost_d_output = output - target
        d_output_d_z = sigmoid_derivative(z)
        
        # Gradients for weight and bias
        d_cost_d_w = d_cost_d_output * d_output_d_z * 1  # Since input x = 1
        d_cost_d_b = d_cost_d_output * d_output_d_z
        
        # Update weight and bias
        w -= learning_rate * d_cost_d_w
        b -= learning_rate * d_cost_d_b

    return w, b, costs

# Parameters for Case 1
w1, b1 = 0.60, 0.90  # Initial weight and bias for case 1
learning_rate1 = 0.1  # Learning rate for case 1
epochs = 300

# Run gradient descent for case 1
w1, b1, costs1 = gradient_descent(w1, b1, learning_rate1, epochs)

# Parameters for Case 2
w2, b2 = 2.00, 2.00  # Initial weight and bias for case 2
learning_rate2 = 0.1  # Learning rate for case 2

# Run gradient descent for case 2
w2, b2, costs2 = gradient_descent(w2, b2, learning_rate2, epochs)

# Plot the learning curves for both cases
plt.plot(costs1, label='Case 1: w=0.6, b=0.9')
plt.plot(costs2, label='Case 2: w=2.0, b=2.0')
plt.xlabel('Epoch')
plt.ylabel('Cost')
plt.title('Learning Curve: Cost vs Epoch')
plt.legend()
plt.grid(True)
plt.show()
